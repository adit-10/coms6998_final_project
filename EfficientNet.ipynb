# %% [markdown]
# # EfficientNet Optimization

# %% [markdown]
# #### Model creation

# %%
# !pip install -q tensorflow-model-optimization

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import tempfile
import zipfile
import os

# %%
from tensorflow.keras.applications import ResNet50, MobileNet, EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, UpSampling2D, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)
y_train = np_utils.to_categorical(y_train, 100)
y_test = np_utils.to_categorical(y_test, 100)

# %% [markdown]
# #### Create functional model

# %%
def get_model():
    efficientNet_imagenet_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

    #Flatten output layer of Resnet
    gfp = GlobalAveragePooling2D()(efficientNet_imagenet_model.output)

    #flattened = tf.keras.layers.Flatten()(resnet50_imagenet_model.output)

    #Fully connected layer 1
    fc1 = Dense(256, activation='relu', name="AddedDense1")(gfp)

    #Fully connected layer, output layer
    fc2 = Dense(100, activation='softmax', name="AddedDense2")(fc1)

    model = tf.keras.models.Model(inputs=efficientNet_imagenet_model.input, outputs=fc2)
    return model

# %%
model = get_model()

# %%
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #### Model training

# %%
model.fit(x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 782/782 [==============================] - 34s 43ms/step - loss: 2.8584 - accuracy: 0.2983 - val_loss: 2.1876 - val_accuracy: 0.4183
# Epoch 2/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.9909 - accuracy: 0.4654 - val_loss: 1.9502 - val_accuracy: 0.4874
# Epoch 3/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.6987 - accuracy: 0.5333 - val_loss: 1.8451 - val_accuracy: 0.5119
# Epoch 4/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.4854 - accuracy: 0.5834 - val_loss: 1.7472 - val_accuracy: 0.5320
# Epoch 5/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3380 - accuracy: 0.6189 - val_loss: 1.7693 - val_accuracy: 0.5458
# Epoch 6/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.2174 - accuracy: 0.6459 - val_loss: 1.7649 - val_accuracy: 0.5464
# Epoch 7/25
# 782/782 [==============================] - 32s 41ms/step - loss: 1.0984 - accuracy: 0.6756 - val_loss: 1.7583 - val_accuracy: 0.5562
# Epoch 8/25
# 782/782 [==============================] - 33s 42ms/step - loss: 1.0031 - accuracy: 0.7000 - val_loss: 1.8825 - val_accuracy: 0.5427
# Epoch 9/25
# 782/782 [==============================] - 33s 43ms/step - loss: 0.9120 - accuracy: 0.7242 - val_loss: 1.8622 - val_accuracy: 0.5501
# Epoch 10/25
# 782/782 [==============================] - 33s 43ms/step - loss: 0.8498 - accuracy: 0.7422 - val_loss: 1.9179 - val_accuracy: 0.5485
# Epoch 11/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7885 - accuracy: 0.7586 - val_loss: 1.9161 - val_accuracy: 0.5575
# Epoch 12/25
# 782/782 [==============================] - 33s 43ms/step - loss: 0.7290 - accuracy: 0.7749 - val_loss: 1.9604 - val_accuracy: 0.5620
# Epoch 13/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6679 - accuracy: 0.7931 - val_loss: 2.0452 - val_accuracy: 0.5626
# Epoch 14/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6390 - accuracy: 0.8037 - val_loss: 2.0197 - val_accuracy: 0.5669
# Epoch 15/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6022 - accuracy: 0.8123 - val_loss: 2.1589 - val_accuracy: 0.5506
# Epoch 16/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5537 - accuracy: 0.8260 - val_loss: 2.1266 - val_accuracy: 0.5592
# Epoch 17/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5318 - accuracy: 0.8342 - val_loss: 2.1744 - val_accuracy: 0.5652
# Epoch 18/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4997 - accuracy: 0.8420 - val_loss: 2.2828 - val_accuracy: 0.5527
# Epoch 19/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4727 - accuracy: 0.8534 - val_loss: 2.3480 - val_accuracy: 0.5509
# Epoch 20/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4615 - accuracy: 0.8557 - val_loss: 2.2568 - val_accuracy: 0.5615
# Epoch 21/25
# 782/782 [==============================] - 32s 42ms/step - loss: 0.4341 - accuracy: 0.8633 - val_loss: 2.3408 - val_accuracy: 0.5540
# Epoch 22/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4227 - accuracy: 0.8671 - val_loss: 2.3756 - val_accuracy: 0.5562
# Epoch 23/25
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4050 - accuracy: 0.8728 - val_loss: 2.4237 - val_accuracy: 0.5570
# Epoch 24/25
# 782/782 [==============================] - 32s 42ms/step - loss: 0.4001 - accuracy: 0.8729 - val_loss: 2.3933 - val_accuracy: 0.5614
# Epoch 25/25
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3840 - accuracy: 0.8782 - val_loss: 2.3910 - val_accuracy: 0.5667

# %% [markdown]
# # Quantization

# %% [markdown]
# #### Convert model to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /tmp/tmpdf7_eh7p/assets

# %% [markdown]
# #### Dynamic range quantization
# The simplest form of post-training quantization statically quantizes only the weights from floating point to integer, which has 8-bits of precision:

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model_dynamic_quant = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp64s7jpbq/assets
# INFO:tensorflow:Assets written to: /tmp/tmp64s7jpbq/assets

# %% [markdown]
# #### Full integer quantization

# %%
def representative_data_gen():
    for input_value in tf.data.Dataset.from_tensor_slices(x_train).batch(1).take(100):
    # Model has only one input so each data point has one element.
        yield [input_value]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen

tflite_model_full_integer_quant = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpuh1x2s1u/assets
# INFO:tensorflow:Assets written to: /tmp/tmpuh1x2s1u/assets

# %% [markdown]
# #### Float 16 quant

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
tflite_model_float16_quant = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp0a47srxv/assets
# INFO:tensorflow:Assets written to: /tmp/tmp0a47srxv/assets

# %%
import pathlib

tflite_models_dir = pathlib.Path("/tmp/cifar100_tflite_models/")
tflite_models_dir.mkdir(exist_ok=True, parents=True)

# Save the unquantized/float model:
tflite_model_file = tflite_models_dir/"cifar100_model.tflite"
tflite_model_file.write_bytes(tflite_model)
# Save the quantized model:
tflite_model_dynamic_quant_file = tflite_models_dir/"cifar100_tflite_model_dynamic_quant.tflite"
tflite_model_dynamic_quant_file.write_bytes(tflite_model_dynamic_quant)
# Save the quantized model:
tflite_model_full_integer_quant_file = tflite_models_dir/"cifar100_tflite_model_full_integer_quant.tflite"
tflite_model_full_integer_quant_file.write_bytes(tflite_model_full_integer_quant)
# Save the quantized model:
tflite_model_float16_quant_file = tflite_models_dir/"cifar100_tflite_model_float16_quant.tflite"
tflite_model_float16_quant_file.write_bytes(tflite_model_float16_quant)
# Out:
# 8803072

# %% [markdown]
# #### Check tflite model size

# %%
# !ls /tmp/cifar100_tflite_models/ -lh
# Out:
# total 35M
# -rw-r--r-- 1 jupyter jupyter  17M Apr 22 00:36 cifar100_model.tflite
# -rw-r--r-- 1 jupyter jupyter 4.4M Apr 22 00:36 cifar100_tflite_model_dynamic_quant.tflite
# -rw-r--r-- 1 jupyter jupyter 8.4M Apr 22 00:36 cifar100_tflite_model_float16_quant.tflite
# -rw-r--r-- 1 jupyter jupyter 5.3M Apr 22 00:36 cifar100_tflite_model_full_integer_quant.tflite

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)

# %%
test_images = x_train
test_labels = y_train[:,0]
# test_labels = y_train[:1000]

y_test = y_test[:,0]

# %% [markdown]
# #### Quantized model evalutation

# %%
# Helper function to run inference on a TFLite model
def run_tflite_model(tflite_file, test_image_indices):
    global test_images

    # Initialize the interpreter
    interpreter = tf.lite.Interpreter(model_path=str(tflite_file))
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]

    predictions = np.zeros((len(test_image_indices),), dtype=int)
    for i, test_image_index in enumerate(test_image_indices):
    #print(i)
        test_image = x_test[test_image_index]
        test_label = y_test[test_image_index]

    # Check if the input type is quantized, then rescale input data to uint8
        if input_details['dtype'] == np.uint8:
            input_scale, input_zero_point = input_details["quantization"]
            test_image = test_image / input_scale + input_zero_point

        test_image = np.expand_dims(test_image, axis=0).astype(input_details["dtype"])
        interpreter.set_tensor(input_details["index"], test_image)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details["index"])[0]

        predictions[i] = output.argmax()

    return predictions

# %%
#Check change in accuracy

def evaluate_model(tflite_file, model_type):
    global x_test
    global y_test

    test_image_indices = range(x_test.shape[0])
    predictions = run_tflite_model(tflite_file, test_image_indices)
    #print(predictions)

    accuracy = (np.sum(y_test== predictions) * 100) / len(x_test)

    print('%s model accuracy is %.4f%% (Number of test samples=%d)' % (
      model_type, accuracy, len(x_test)))

# %%
import numpy as np
tflite_model = evaluate_model(tflite_model_file, model_type="float")
# Out:
# float model accuracy is 56.5500% (Number of test samples=10000)

# %%
tflite_dynamic_quant_accuracy = evaluate_model(tflite_model_dynamic_quant_file, model_type="Quantized")
# Out:
# Quantized model accuracy is 38.7400% (Number of test samples=10000)

# %%
tflite_full_integer_quant_accuracy = evaluate_model(tflite_model_full_integer_quant_file, model_type="Quantized")
# Out:
# Quantized model accuracy is 51.2900% (Number of test samples=10000)

# %%
tflite_float16_quant_accuracy = evaluate_model(tflite_model_float16_quant_file, model_type="Quantized")
# Out:
# Quantized model accuracy is 56.5800% (Number of test samples=10000)

# %%
# !ls /tmp/cifar100_tflite_models/ -lh
# Out:
# total 35M
# -rw-r--r-- 1 jupyter jupyter  17M Apr 22 00:36 cifar100_model.tflite
# -rw-r--r-- 1 jupyter jupyter 4.4M Apr 22 00:36 cifar100_tflite_model_dynamic_quant.tflite
# -rw-r--r-- 1 jupyter jupyter 8.4M Apr 22 00:36 cifar100_tflite_model_float16_quant.tflite
# -rw-r--r-- 1 jupyter jupyter 5.3M Apr 22 00:36 cifar100_tflite_model_full_integer_quant.tflite

# %% [markdown]
# ## Pruning

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_callbacks
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_schedule

# %%
def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)
y_train = np_utils.to_categorical(y_train, 100)
y_test = np_utils.to_categorical(y_test, 100)

# %% [markdown]
# #### Check baseline model accuracy

# %%
_, baseline_model_accuracy = model.evaluate(
    x_test, y_test, verbose=0)

print('Baseline test accuracy:', baseline_model_accuracy)

_, keras_file = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model, keras_file, include_optimizer=False)
print('Saved baseline model to:', keras_file)
# Out:
# Baseline test accuracy: 0.5666999816894531
# Saved baseline model to: /tmp/tmpnbtuzij9.h5

# %%
# !ls /tmp/tmpkw6weg2f.h5 -lh
# Out:
# -rw------- 1 jupyter jupyter 18M Apr 21 20:46 /tmp/tmpkw6weg2f.h5

# %%
def apply_pruning_to_dense(layer):
    if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, ps)
    return layer

# %%
import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

# Compute end step to finish pruning after 2 epochs.
batch_size = 128
epochs = 2
validation_split = 0.1 # 10% of training set will be used for validation set. 

num_images = x_train.shape[0] * (1 - validation_split)
end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs

# %% [markdown]
# #### Pruning at 0.2 Sparsity

# %%
def apply_pruning_to_dense(layer):
    if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, ps)
    return layer

ps = pruning_schedule.PolynomialDecay(
                 initial_sparsity=0.20, final_sparsity=0.20,
                       begin_step=0, end_step=end_step, frequency=100)

model_for_pruning_2 = tf.keras.models.clone_model(
    model,
    clone_function=apply_pruning_to_dense,
)

# `prune_low_magnitude` requires a recompile.
model_for_pruning_2.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_for_pruning_2.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 32, 32, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# normalization_1 (Normalization) (None, 32, 32, 3)    7           rescaling_1[17][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_1[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_conv ( (None, 16, 16, 32)   1730        stem_conv_pad[17][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 16, 16, 32)   128         prune_low_magnitude_stem_conv[0][
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 16, 16, 32)   0           stem_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_dwc (None, 16, 16, 32)   289         stem_activation[17][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 16, 16, 32)   128         prune_low_magnitude_block1a_dwcon
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 16, 16, 32)   0           block1a_bn[17][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[17][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 8)      522         block1a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 32)     546         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 16, 16, 32)   0           block1a_activation[17][0]
#                                                                  prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, 16, 16, 16)   1026        block1a_se_excite[17][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 16, 16, 16)   64          prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, 16, 16, 96)   3074        block1a_project_bn[17][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 16, 16, 96)   384         prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 16, 16, 96)   0           block2a_expand_bn[17][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 17, 17, 96)   0           block2a_expand_activation[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_dwc (None, 8, 8, 96)     865         block2a_dwconv_pad[17][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 8, 8, 96)     384         prune_low_magnitude_block2a_dwcon
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 8, 8, 96)     0           block2a_bn[17][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[17][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 4)      774         block2a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 96)     866         prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 8, 8, 96)     0           block2a_activation[17][0]
#                                                                  prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, 8, 8, 24)     4610        block2a_se_excite[17][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, 8, 8, 144)    6914        block2a_project_bn[17][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 8, 8, 144)    0           block2b_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dwc (None, 8, 8, 144)    1297        block2b_expand_activation[17][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 8, 8, 144)    576         prune_low_magnitude_block2b_dwcon
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 8, 8, 144)    0           block2b_bn[17][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[17][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 6)      1736        block2b_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 8, 8, 144)    0           block2b_activation[17][0]
#                                                                  prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, 8, 8, 24)     6914        block2b_se_excite[17][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 8, 8, 24)     0           block2b_project_bn[17][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 8, 8, 24)     0           block2b_drop[17][0]
#                                                                  block2a_project_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, 8, 8, 144)    6914        block2b_add[17][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 8, 8, 144)    0           block3a_expand_bn[17][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 11, 11, 144)  0           block3a_expand_activation[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_dwc (None, 4, 4, 144)    3601        block3a_dwconv_pad[17][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 4, 4, 144)    576         prune_low_magnitude_block3a_dwcon
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 4, 4, 144)    0           block3a_bn[17][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[17][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 6)      1736        block3a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 4, 4, 144)    0           block3a_activation[17][0]
#                                                                  prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, 4, 4, 40)     11522       block3a_se_excite[17][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, 4, 4, 240)    19202       block3a_project_bn[17][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 4, 4, 240)    0           block3b_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dwc (None, 4, 4, 240)    6001        block3b_expand_activation[17][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 4, 4, 240)    960         prune_low_magnitude_block3b_dwcon
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 4, 4, 240)    0           block3b_bn[17][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[17][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 10)     4812        block3b_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 4, 4, 240)    0           block3b_activation[17][0]
#                                                                  prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, 4, 4, 40)     19202       block3b_se_excite[17][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 4, 4, 40)     0           block3b_project_bn[17][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 4, 4, 40)     0           block3b_drop[17][0]
#                                                                  block3a_project_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, 4, 4, 240)    19202       block3b_add[17][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 4, 4, 240)    0           block4a_expand_bn[17][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 5, 5, 240)    0           block4a_expand_activation[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_dwc (None, 2, 2, 240)    2161        block4a_dwconv_pad[17][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 2, 2, 240)    960         prune_low_magnitude_block4a_dwcon
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 2, 2, 240)    0           block4a_bn[17][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[17][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 10)     4812        block4a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 2, 2, 240)    0           block4a_activation[17][0]
#                                                                  prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, 2, 2, 80)     38402       block4a_se_excite[17][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, 2, 2, 480)    76802       block4a_project_bn[17][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 2, 2, 480)    0           block4b_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dwc (None, 2, 2, 480)    4321        block4b_expand_activation[17][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_dwcon
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 2, 2, 480)    0           block4b_bn[17][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[17][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 20)     19222       block4b_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 2, 2, 480)    0           block4b_activation[17][0]
#                                                                  prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, 2, 2, 80)     76802       block4b_se_excite[17][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 2, 2, 80)     0           block4b_project_bn[17][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 2, 2, 80)     0           block4b_drop[17][0]
#                                                                  block4a_project_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, 2, 2, 480)    76802       block4b_add[17][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 2, 2, 480)    0           block4c_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dwc (None, 2, 2, 480)    4321        block4c_expand_activation[17][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_dwcon
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 2, 2, 480)    0           block4c_bn[17][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[17][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 20)     19222       block4c_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 2, 2, 480)    0           block4c_activation[17][0]
#                                                                  prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, 2, 2, 80)     76802       block4c_se_excite[17][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 2, 2, 80)     0           block4c_project_bn[17][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 2, 2, 80)     0           block4c_drop[17][0]
#                                                                  block4b_add[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, 2, 2, 480)    76802       block4c_add[17][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 2, 2, 480)    0           block5a_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_dwc (None, 2, 2, 480)    12001       block5a_expand_activation[17][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_dwcon
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 2, 2, 480)    0           block5a_bn[17][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[17][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 20)     19222       block5a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 2, 2, 480)    0           block5a_activation[17][0]
#                                                                  prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, 2, 2, 112)    107522      block5a_se_excite[17][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, 2, 2, 672)    150530      block5a_project_bn[17][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 2, 2, 672)    0           block5b_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dwc (None, 2, 2, 672)    16801       block5b_expand_activation[17][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_dwcon
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 2, 2, 672)    0           block5b_bn[17][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[17][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 28)     37662       block5b_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 2, 2, 672)    0           block5b_activation[17][0]
#                                                                  prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, 2, 2, 112)    150530      block5b_se_excite[17][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 2, 2, 112)    0           block5b_project_bn[17][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 2, 2, 112)    0           block5b_drop[17][0]
#                                                                  block5a_project_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, 2, 2, 672)    150530      block5b_add[17][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 2, 2, 672)    0           block5c_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dwc (None, 2, 2, 672)    16801       block5c_expand_activation[17][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_dwcon
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 2, 2, 672)    0           block5c_bn[17][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[17][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 28)     37662       block5c_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 2, 2, 672)    0           block5c_activation[17][0]
#                                                                  prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, 2, 2, 112)    150530      block5c_se_excite[17][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 2, 2, 112)    0           block5c_project_bn[17][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 2, 2, 112)    0           block5c_drop[17][0]
#                                                                  block5b_add[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_exp (None, 2, 2, 672)    150530      block5c_add[17][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block6a_expan
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 2, 2, 672)    0           block6a_expand_bn[17][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 5, 5, 672)    0           block6a_expand_activation[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_dwc (None, 1, 1, 672)    16801       block6a_dwconv_pad[17][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 1, 1, 672)    2688        prune_low_magnitude_block6a_dwcon
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 1, 1, 672)    0           block6a_bn[17][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[17][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 28)     37662       block6a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block6a_se_re
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 1, 1, 672)    0           block6a_activation[17][0]
#                                                                  prune_low_magnitude_block6a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_pro (None, 1, 1, 192)    258050      block6a_se_excite[17][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_exp (None, 1, 1, 1152)   442370      block6a_project_bn[17][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_expan
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 1, 1, 1152)   0           block6b_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_dwc (None, 1, 1, 1152)   28801       block6b_expand_activation[17][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_dwcon
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 1, 1, 1152)   0           block6b_bn[17][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[17][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 48)     110642      block6b_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6b_se_re
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6b_activation[17][0]
#                                                                  prune_low_magnitude_block6b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_pro (None, 1, 1, 192)    442370      block6b_se_excite[17][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6b_proje
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 1, 1, 192)    0           block6b_project_bn[17][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 1, 1, 192)    0           block6b_drop[17][0]
#                                                                  block6a_project_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_exp (None, 1, 1, 1152)   442370      block6b_add[17][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_expan
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 1, 1, 1152)   0           block6c_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_dwc (None, 1, 1, 1152)   28801       block6c_expand_activation[17][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_dwcon
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 1, 1, 1152)   0           block6c_bn[17][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[17][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 48)     110642      block6c_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6c_se_re
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6c_activation[17][0]
#                                                                  prune_low_magnitude_block6c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_pro (None, 1, 1, 192)    442370      block6c_se_excite[17][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6c_proje
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 1, 1, 192)    0           block6c_project_bn[17][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 1, 1, 192)    0           block6c_drop[17][0]
#                                                                  block6b_add[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_exp (None, 1, 1, 1152)   442370      block6c_add[17][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_expan
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 1, 1, 1152)   0           block6d_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_dwc (None, 1, 1, 1152)   28801       block6d_expand_activation[17][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_dwcon
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 1, 1, 1152)   0           block6d_bn[17][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[17][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 48)     110642      block6d_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6d_se_re
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6d_activation[17][0]
#                                                                  prune_low_magnitude_block6d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_pro (None, 1, 1, 192)    442370      block6d_se_excite[17][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6d_proje
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 1, 1, 192)    0           block6d_project_bn[17][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 1, 1, 192)    0           block6d_drop[17][0]
#                                                                  block6c_add[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, 1, 1, 1152)   442370      block6d_add[17][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 1, 1, 1152)   0           block7a_expand_bn[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_dwc (None, 1, 1, 1152)   10369       block7a_expand_activation[17][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_dwcon
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 1, 1, 1152)   0           block7a_bn[17][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[17][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 48)     110642      block7a_se_reshape[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 1, 1, 1152)   0           block7a_activation[17][0]
#                                                                  prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, 1, 1, 320)    737282      block7a_se_excite[17][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 1, 1, 320)    1280        prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_top_conv (P (None, 1, 1, 1280)   819202      block7a_project_bn[17][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 1, 1, 1280)   5120        prune_low_magnitude_top_conv[0][0
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 1, 1, 1280)   0           top_bn[17][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           top_activation[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense1 (None, 256)          655618      global_average_pooling2d[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense2 (None, 100)          51302       prune_low_magnitude_AddedDense1[0
# ==================================================================================================
# Total params: 8,530,813
# Trainable params: 4,361,184
# Non-trainable params: 4,169,629
# __________________________________________________________________________________________________

# %%
model_for_pruning_2.fit(x_train, y_train, batch_size=64, epochs=6, validation_data=(x_test, y_test), callbacks = [pruning_callbacks.UpdatePruningStep()])
# Out:
# Epoch 1/6
# 782/782 [==============================] - 64s 82ms/step - loss: 4.0531 - accuracy: 0.5705 - val_loss: 4.1727 - val_accuracy: 0.4502
# Epoch 2/6
# 782/782 [==============================] - 61s 78ms/step - loss: 4.0808 - accuracy: 0.5416 - val_loss: 4.1779 - val_accuracy: 0.4440
# Epoch 3/6
# 782/782 [==============================] - 61s 78ms/step - loss: 4.0903 - accuracy: 0.5327 - val_loss: 4.1852 - val_accuracy: 0.4371
# Epoch 4/6
# 782/782 [==============================] - 61s 78ms/step - loss: 4.0985 - accuracy: 0.5238 - val_loss: 4.1724 - val_accuracy: 0.4495
# Epoch 5/6
# 782/782 [==============================] - 60s 77ms/step - loss: 4.0923 - accuracy: 0.5303 - val_loss: 4.1743 - val_accuracy: 0.4481
# Epoch 6/6
# 782/782 [==============================] - 61s 78ms/step - loss: 4.0971 - accuracy: 0.5252 - val_loss: 4.1703 - val_accuracy: 0.4531

# %%
model_for_export_2 = tfmot.sparsity.keras.strip_pruning(model_for_pruning_2)
_, pruned_keras_file_2 = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export_2, pruned_keras_file_2, include_optimizer=False)
print('Saved pruned Keras model to:', pruned_keras_file_2)
# Out:
# Saved pruned Keras model to: /tmp/tmpqkmvx0f_.h5

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export_2)
pruned_tflite_model_2 = converter.convert()

_, pruned_tflite_file_2 = tempfile.mkstemp('.tflite')

with open(pruned_tflite_file_2, 'wb') as f:
    f.write(pruned_tflite_model_2)

print('Saved pruned TFLite model to:', pruned_tflite_file_2)
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_2)))
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp39zfticp/assets
# INFO:tensorflow:Assets written to: /tmp/tmp39zfticp/assets
# Saved pruned TFLite model to: /tmp/tmpkka9cajx.tflite
# Size of gzipped pruned and quantized TFlite model: 14383280.00 bytes

# %%
_, model_for_pruning_2_accuracy = model_for_pruning_2.evaluate(
   x_test, y_test, verbose=0)

print('Baseline test accuracy:', baseline_model_accuracy) 
print('Pruned at 0.2 Sparsity test accuracy:', model_for_pruning_2_accuracy)
# Out:
# Baseline test accuracy: 0.565500020980835
# Pruned at 0.2 Sparsity test accuracy: 0.4530999958515167

# %% [markdown]
# #### Pruning at 0.4 Sparsity

# %%
def apply_pruning_to_dense(layer):
    if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, ps)
    return layer

ps = pruning_schedule.PolynomialDecay(
                 initial_sparsity=0.40, final_sparsity=0.40,
                       begin_step=0, end_step=end_step, frequency=100)

model_for_pruning_4 = tf.keras.models.clone_model(
    model,
    clone_function=apply_pruning_to_dense,
)

# `prune_low_magnitude` requires a recompile.
model_for_pruning_4.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_for_pruning_4.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 32, 32, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# normalization_1 (Normalization) (None, 32, 32, 3)    7           rescaling_1[19][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_1[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_conv ( (None, 16, 16, 32)   1730        stem_conv_pad[19][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 16, 16, 32)   128         prune_low_magnitude_stem_conv[0][
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 16, 16, 32)   0           stem_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_dwc (None, 16, 16, 32)   289         stem_activation[19][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 16, 16, 32)   128         prune_low_magnitude_block1a_dwcon
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 16, 16, 32)   0           block1a_bn[19][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[19][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 8)      522         block1a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 32)     546         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 16, 16, 32)   0           block1a_activation[19][0]
#                                                                  prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, 16, 16, 16)   1026        block1a_se_excite[19][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 16, 16, 16)   64          prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, 16, 16, 96)   3074        block1a_project_bn[19][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 16, 16, 96)   384         prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 16, 16, 96)   0           block2a_expand_bn[19][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 17, 17, 96)   0           block2a_expand_activation[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_dwc (None, 8, 8, 96)     865         block2a_dwconv_pad[19][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 8, 8, 96)     384         prune_low_magnitude_block2a_dwcon
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 8, 8, 96)     0           block2a_bn[19][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[19][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 4)      774         block2a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 96)     866         prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 8, 8, 96)     0           block2a_activation[19][0]
#                                                                  prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, 8, 8, 24)     4610        block2a_se_excite[19][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, 8, 8, 144)    6914        block2a_project_bn[19][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 8, 8, 144)    0           block2b_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dwc (None, 8, 8, 144)    1297        block2b_expand_activation[19][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 8, 8, 144)    576         prune_low_magnitude_block2b_dwcon
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 8, 8, 144)    0           block2b_bn[19][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[19][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 6)      1736        block2b_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 8, 8, 144)    0           block2b_activation[19][0]
#                                                                  prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, 8, 8, 24)     6914        block2b_se_excite[19][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 8, 8, 24)     0           block2b_project_bn[19][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 8, 8, 24)     0           block2b_drop[19][0]
#                                                                  block2a_project_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, 8, 8, 144)    6914        block2b_add[19][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 8, 8, 144)    0           block3a_expand_bn[19][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 11, 11, 144)  0           block3a_expand_activation[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_dwc (None, 4, 4, 144)    3601        block3a_dwconv_pad[19][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 4, 4, 144)    576         prune_low_magnitude_block3a_dwcon
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 4, 4, 144)    0           block3a_bn[19][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[19][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 6)      1736        block3a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 4, 4, 144)    0           block3a_activation[19][0]
#                                                                  prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, 4, 4, 40)     11522       block3a_se_excite[19][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, 4, 4, 240)    19202       block3a_project_bn[19][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 4, 4, 240)    0           block3b_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dwc (None, 4, 4, 240)    6001        block3b_expand_activation[19][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 4, 4, 240)    960         prune_low_magnitude_block3b_dwcon
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 4, 4, 240)    0           block3b_bn[19][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[19][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 10)     4812        block3b_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 4, 4, 240)    0           block3b_activation[19][0]
#                                                                  prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, 4, 4, 40)     19202       block3b_se_excite[19][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 4, 4, 40)     0           block3b_project_bn[19][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 4, 4, 40)     0           block3b_drop[19][0]
#                                                                  block3a_project_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, 4, 4, 240)    19202       block3b_add[19][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 4, 4, 240)    0           block4a_expand_bn[19][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 5, 5, 240)    0           block4a_expand_activation[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_dwc (None, 2, 2, 240)    2161        block4a_dwconv_pad[19][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 2, 2, 240)    960         prune_low_magnitude_block4a_dwcon
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 2, 2, 240)    0           block4a_bn[19][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[19][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 10)     4812        block4a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 2, 2, 240)    0           block4a_activation[19][0]
#                                                                  prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, 2, 2, 80)     38402       block4a_se_excite[19][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, 2, 2, 480)    76802       block4a_project_bn[19][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 2, 2, 480)    0           block4b_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dwc (None, 2, 2, 480)    4321        block4b_expand_activation[19][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_dwcon
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 2, 2, 480)    0           block4b_bn[19][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[19][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 20)     19222       block4b_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 2, 2, 480)    0           block4b_activation[19][0]
#                                                                  prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, 2, 2, 80)     76802       block4b_se_excite[19][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 2, 2, 80)     0           block4b_project_bn[19][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 2, 2, 80)     0           block4b_drop[19][0]
#                                                                  block4a_project_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, 2, 2, 480)    76802       block4b_add[19][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 2, 2, 480)    0           block4c_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dwc (None, 2, 2, 480)    4321        block4c_expand_activation[19][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_dwcon
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 2, 2, 480)    0           block4c_bn[19][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[19][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 20)     19222       block4c_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 2, 2, 480)    0           block4c_activation[19][0]
#                                                                  prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, 2, 2, 80)     76802       block4c_se_excite[19][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 2, 2, 80)     0           block4c_project_bn[19][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 2, 2, 80)     0           block4c_drop[19][0]
#                                                                  block4b_add[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, 2, 2, 480)    76802       block4c_add[19][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 2, 2, 480)    0           block5a_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_dwc (None, 2, 2, 480)    12001       block5a_expand_activation[19][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_dwcon
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 2, 2, 480)    0           block5a_bn[19][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[19][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 20)     19222       block5a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 2, 2, 480)    0           block5a_activation[19][0]
#                                                                  prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, 2, 2, 112)    107522      block5a_se_excite[19][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, 2, 2, 672)    150530      block5a_project_bn[19][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 2, 2, 672)    0           block5b_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dwc (None, 2, 2, 672)    16801       block5b_expand_activation[19][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_dwcon
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 2, 2, 672)    0           block5b_bn[19][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[19][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 28)     37662       block5b_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 2, 2, 672)    0           block5b_activation[19][0]
#                                                                  prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, 2, 2, 112)    150530      block5b_se_excite[19][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 2, 2, 112)    0           block5b_project_bn[19][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 2, 2, 112)    0           block5b_drop[19][0]
#                                                                  block5a_project_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, 2, 2, 672)    150530      block5b_add[19][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 2, 2, 672)    0           block5c_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dwc (None, 2, 2, 672)    16801       block5c_expand_activation[19][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_dwcon
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 2, 2, 672)    0           block5c_bn[19][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[19][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 28)     37662       block5c_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 2, 2, 672)    0           block5c_activation[19][0]
#                                                                  prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, 2, 2, 112)    150530      block5c_se_excite[19][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 2, 2, 112)    0           block5c_project_bn[19][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 2, 2, 112)    0           block5c_drop[19][0]
#                                                                  block5b_add[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_exp (None, 2, 2, 672)    150530      block5c_add[19][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block6a_expan
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 2, 2, 672)    0           block6a_expand_bn[19][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 5, 5, 672)    0           block6a_expand_activation[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_dwc (None, 1, 1, 672)    16801       block6a_dwconv_pad[19][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 1, 1, 672)    2688        prune_low_magnitude_block6a_dwcon
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 1, 1, 672)    0           block6a_bn[19][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[19][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 28)     37662       block6a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block6a_se_re
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 1, 1, 672)    0           block6a_activation[19][0]
#                                                                  prune_low_magnitude_block6a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_pro (None, 1, 1, 192)    258050      block6a_se_excite[19][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_exp (None, 1, 1, 1152)   442370      block6a_project_bn[19][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_expan
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 1, 1, 1152)   0           block6b_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_dwc (None, 1, 1, 1152)   28801       block6b_expand_activation[19][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_dwcon
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 1, 1, 1152)   0           block6b_bn[19][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[19][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 48)     110642      block6b_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6b_se_re
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6b_activation[19][0]
#                                                                  prune_low_magnitude_block6b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_pro (None, 1, 1, 192)    442370      block6b_se_excite[19][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6b_proje
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 1, 1, 192)    0           block6b_project_bn[19][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 1, 1, 192)    0           block6b_drop[19][0]
#                                                                  block6a_project_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_exp (None, 1, 1, 1152)   442370      block6b_add[19][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_expan
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 1, 1, 1152)   0           block6c_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_dwc (None, 1, 1, 1152)   28801       block6c_expand_activation[19][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_dwcon
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 1, 1, 1152)   0           block6c_bn[19][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[19][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 48)     110642      block6c_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6c_se_re
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6c_activation[19][0]
#                                                                  prune_low_magnitude_block6c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_pro (None, 1, 1, 192)    442370      block6c_se_excite[19][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6c_proje
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 1, 1, 192)    0           block6c_project_bn[19][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 1, 1, 192)    0           block6c_drop[19][0]
#                                                                  block6b_add[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_exp (None, 1, 1, 1152)   442370      block6c_add[19][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_expan
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 1, 1, 1152)   0           block6d_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_dwc (None, 1, 1, 1152)   28801       block6d_expand_activation[19][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_dwcon
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 1, 1, 1152)   0           block6d_bn[19][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[19][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 48)     110642      block6d_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6d_se_re
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6d_activation[19][0]
#                                                                  prune_low_magnitude_block6d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_pro (None, 1, 1, 192)    442370      block6d_se_excite[19][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6d_proje
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 1, 1, 192)    0           block6d_project_bn[19][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 1, 1, 192)    0           block6d_drop[19][0]
#                                                                  block6c_add[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, 1, 1, 1152)   442370      block6d_add[19][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 1, 1, 1152)   0           block7a_expand_bn[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_dwc (None, 1, 1, 1152)   10369       block7a_expand_activation[19][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_dwcon
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 1, 1, 1152)   0           block7a_bn[19][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[19][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 48)     110642      block7a_se_reshape[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 1, 1, 1152)   0           block7a_activation[19][0]
#                                                                  prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, 1, 1, 320)    737282      block7a_se_excite[19][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 1, 1, 320)    1280        prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_top_conv (P (None, 1, 1, 1280)   819202      block7a_project_bn[19][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 1, 1, 1280)   5120        prune_low_magnitude_top_conv[0][0
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 1, 1, 1280)   0           top_bn[19][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           top_activation[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense1 (None, 256)          655618      global_average_pooling2d[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense2 (None, 100)          51302       prune_low_magnitude_AddedDense1[0
# ==================================================================================================
# Total params: 8,530,813
# Trainable params: 4,361,184
# Non-trainable params: 4,169,629
# __________________________________________________________________________________________________

# %%
model_for_pruning_4.fit(x_train, y_train, batch_size=64, epochs=6, validation_data=(x_test, y_test), callbacks = [pruning_callbacks.UpdatePruningStep()])
# Out:
# Epoch 1/6
# 782/782 [==============================] - 62s 80ms/step - loss: 4.0729 - accuracy: 0.5497 - val_loss: 4.1623 - val_accuracy: 0.4603
# Epoch 2/6
# 782/782 [==============================] - 60s 77ms/step - loss: 4.0566 - accuracy: 0.5659 - val_loss: 4.1487 - val_accuracy: 0.4741
# Epoch 3/6
# 782/782 [==============================] - 60s 77ms/step - loss: 4.0498 - accuracy: 0.5724 - val_loss: 4.1548 - val_accuracy: 0.4672
# Epoch 4/6
# 782/782 [==============================] - 59s 76ms/step - loss: 4.0470 - accuracy: 0.5757 - val_loss: 4.1478 - val_accuracy: 0.4752
# Epoch 5/6
# 782/782 [==============================] - 60s 77ms/step - loss: 4.0463 - accuracy: 0.5760 - val_loss: 4.1457 - val_accuracy: 0.4774
# Epoch 6/6
# 782/782 [==============================] - 59s 76ms/step - loss: 4.0426 - accuracy: 0.5798 - val_loss: 4.1398 - val_accuracy: 0.4817

# %%
model_for_export_4 = tfmot.sparsity.keras.strip_pruning(model_for_pruning_4)
_, pruned_keras_file_4 = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export_4, pruned_keras_file_4, include_optimizer=False)
print('Saved pruned Keras model to:', pruned_keras_file_4)
# Out:
# Saved pruned Keras model to: /tmp/tmpd3ezdy20.h5

# %%
_, model_for_pruning_4_accuracy = model_for_pruning_4.evaluate(
   x_test, y_test, verbose=0)

print('Baseline test accuracy:', baseline_model_accuracy) 
print('Pruned at 0.2 Sparsity test accuracy:', model_for_pruning_2_accuracy)
print('Pruned at 0.4 Sparsity test accuracy:', model_for_pruning_4_accuracy)
# Out:
# Baseline test accuracy: 0.565500020980835
# Pruned at 0.2 Sparsity test accuracy: 0.4530999958515167
# Pruned at 0.4 Sparsity test accuracy: 0.48170000314712524

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export_4)
pruned_tflite_model_4 = converter.convert()

_, pruned_tflite_file_4 = tempfile.mkstemp('.tflite')

with open(pruned_tflite_file_4, 'wb') as f:
    f.write(pruned_tflite_model_4)

print('Saved pruned TFLite model to:', pruned_tflite_file_4)
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_2)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_4)))
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpdevbci8p/assets
# INFO:tensorflow:Assets written to: /tmp/tmpdevbci8p/assets
# Saved pruned TFLite model to: /tmp/tmpq3u90g6j.tflite
# Size of gzipped pruned and quantized TFlite model: 14383280.00 bytes
# Size of gzipped pruned and quantized TFlite model: 8997139.00 bytes

# %% [markdown]
# #### Pruning at 0.6 Sparsity

# %%
def apply_pruning_to_dense(layer):
    if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, ps)
    return layer

ps = pruning_schedule.PolynomialDecay(
                 initial_sparsity=0.60, final_sparsity=0.60,
                       begin_step=0, end_step=end_step, frequency=100)

model_for_pruning_6 = tf.keras.models.clone_model(
    model,
    clone_function=apply_pruning_to_dense,
)

# `prune_low_magnitude` requires a recompile.
model_for_pruning_6.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_for_pruning_6.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 32, 32, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# normalization_1 (Normalization) (None, 32, 32, 3)    7           rescaling_1[1][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_1[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_conv ( (None, 16, 16, 32)   1730        stem_conv_pad[1][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 16, 16, 32)   128         prune_low_magnitude_stem_conv[0][
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 16, 16, 32)   0           stem_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_dwc (None, 16, 16, 32)   289         stem_activation[1][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 16, 16, 32)   128         prune_low_magnitude_block1a_dwcon
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 16, 16, 32)   0           block1a_bn[1][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[1][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 8)      522         block1a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 32)     546         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 16, 16, 32)   0           block1a_activation[1][0]
#                                                                  prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, 16, 16, 16)   1026        block1a_se_excite[1][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 16, 16, 16)   64          prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, 16, 16, 96)   3074        block1a_project_bn[1][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 16, 16, 96)   384         prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 16, 16, 96)   0           block2a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 17, 17, 96)   0           block2a_expand_activation[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_dwc (None, 8, 8, 96)     865         block2a_dwconv_pad[1][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 8, 8, 96)     384         prune_low_magnitude_block2a_dwcon
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 8, 8, 96)     0           block2a_bn[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 4)      774         block2a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 96)     866         prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 8, 8, 96)     0           block2a_activation[1][0]
#                                                                  prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, 8, 8, 24)     4610        block2a_se_excite[1][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, 8, 8, 144)    6914        block2a_project_bn[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 8, 8, 144)    0           block2b_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dwc (None, 8, 8, 144)    1297        block2b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 8, 8, 144)    576         prune_low_magnitude_block2b_dwcon
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 8, 8, 144)    0           block2b_bn[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 6)      1736        block2b_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 8, 8, 144)    0           block2b_activation[1][0]
#                                                                  prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, 8, 8, 24)     6914        block2b_se_excite[1][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 8, 8, 24)     0           block2b_project_bn[1][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 8, 8, 24)     0           block2b_drop[1][0]
#                                                                  block2a_project_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, 8, 8, 144)    6914        block2b_add[1][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 8, 8, 144)    0           block3a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 11, 11, 144)  0           block3a_expand_activation[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_dwc (None, 4, 4, 144)    3601        block3a_dwconv_pad[1][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 4, 4, 144)    576         prune_low_magnitude_block3a_dwcon
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 4, 4, 144)    0           block3a_bn[1][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[1][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 6)      1736        block3a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 4, 4, 144)    0           block3a_activation[1][0]
#                                                                  prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, 4, 4, 40)     11522       block3a_se_excite[1][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, 4, 4, 240)    19202       block3a_project_bn[1][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 4, 4, 240)    0           block3b_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dwc (None, 4, 4, 240)    6001        block3b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 4, 4, 240)    960         prune_low_magnitude_block3b_dwcon
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 4, 4, 240)    0           block3b_bn[1][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[1][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 10)     4812        block3b_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 4, 4, 240)    0           block3b_activation[1][0]
#                                                                  prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, 4, 4, 40)     19202       block3b_se_excite[1][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 4, 4, 40)     0           block3b_project_bn[1][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 4, 4, 40)     0           block3b_drop[1][0]
#                                                                  block3a_project_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, 4, 4, 240)    19202       block3b_add[1][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 4, 4, 240)    0           block4a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 5, 5, 240)    0           block4a_expand_activation[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_dwc (None, 2, 2, 240)    2161        block4a_dwconv_pad[1][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 2, 2, 240)    960         prune_low_magnitude_block4a_dwcon
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 2, 2, 240)    0           block4a_bn[1][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[1][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 10)     4812        block4a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 2, 2, 240)    0           block4a_activation[1][0]
#                                                                  prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, 2, 2, 80)     38402       block4a_se_excite[1][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, 2, 2, 480)    76802       block4a_project_bn[1][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 2, 2, 480)    0           block4b_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dwc (None, 2, 2, 480)    4321        block4b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_dwcon
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 2, 2, 480)    0           block4b_bn[1][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[1][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 20)     19222       block4b_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 2, 2, 480)    0           block4b_activation[1][0]
#                                                                  prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, 2, 2, 80)     76802       block4b_se_excite[1][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 2, 2, 80)     0           block4b_project_bn[1][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 2, 2, 80)     0           block4b_drop[1][0]
#                                                                  block4a_project_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, 2, 2, 480)    76802       block4b_add[1][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 2, 2, 480)    0           block4c_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dwc (None, 2, 2, 480)    4321        block4c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_dwcon
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 2, 2, 480)    0           block4c_bn[1][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[1][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 20)     19222       block4c_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 2, 2, 480)    0           block4c_activation[1][0]
#                                                                  prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, 2, 2, 80)     76802       block4c_se_excite[1][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 2, 2, 80)     0           block4c_project_bn[1][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 2, 2, 80)     0           block4c_drop[1][0]
#                                                                  block4b_add[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, 2, 2, 480)    76802       block4c_add[1][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 2, 2, 480)    0           block5a_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_dwc (None, 2, 2, 480)    12001       block5a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_dwcon
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 2, 2, 480)    0           block5a_bn[1][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[1][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 20)     19222       block5a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 2, 2, 480)    0           block5a_activation[1][0]
#                                                                  prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, 2, 2, 112)    107522      block5a_se_excite[1][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, 2, 2, 672)    150530      block5a_project_bn[1][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 2, 2, 672)    0           block5b_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dwc (None, 2, 2, 672)    16801       block5b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_dwcon
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 2, 2, 672)    0           block5b_bn[1][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[1][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 28)     37662       block5b_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 2, 2, 672)    0           block5b_activation[1][0]
#                                                                  prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, 2, 2, 112)    150530      block5b_se_excite[1][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 2, 2, 112)    0           block5b_project_bn[1][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 2, 2, 112)    0           block5b_drop[1][0]
#                                                                  block5a_project_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, 2, 2, 672)    150530      block5b_add[1][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 2, 2, 672)    0           block5c_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dwc (None, 2, 2, 672)    16801       block5c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_dwcon
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 2, 2, 672)    0           block5c_bn[1][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[1][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 28)     37662       block5c_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 2, 2, 672)    0           block5c_activation[1][0]
#                                                                  prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, 2, 2, 112)    150530      block5c_se_excite[1][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 2, 2, 112)    0           block5c_project_bn[1][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 2, 2, 112)    0           block5c_drop[1][0]
#                                                                  block5b_add[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_exp (None, 2, 2, 672)    150530      block5c_add[1][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block6a_expan
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 2, 2, 672)    0           block6a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 5, 5, 672)    0           block6a_expand_activation[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_dwc (None, 1, 1, 672)    16801       block6a_dwconv_pad[1][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 1, 1, 672)    2688        prune_low_magnitude_block6a_dwcon
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 1, 1, 672)    0           block6a_bn[1][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[1][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 28)     37662       block6a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block6a_se_re
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 1, 1, 672)    0           block6a_activation[1][0]
#                                                                  prune_low_magnitude_block6a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_pro (None, 1, 1, 192)    258050      block6a_se_excite[1][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_exp (None, 1, 1, 1152)   442370      block6a_project_bn[1][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_expan
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 1, 1, 1152)   0           block6b_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_dwc (None, 1, 1, 1152)   28801       block6b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_dwcon
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 1, 1, 1152)   0           block6b_bn[1][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[1][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 48)     110642      block6b_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6b_se_re
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6b_activation[1][0]
#                                                                  prune_low_magnitude_block6b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_pro (None, 1, 1, 192)    442370      block6b_se_excite[1][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6b_proje
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 1, 1, 192)    0           block6b_project_bn[1][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 1, 1, 192)    0           block6b_drop[1][0]
#                                                                  block6a_project_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_exp (None, 1, 1, 1152)   442370      block6b_add[1][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_expan
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 1, 1, 1152)   0           block6c_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_dwc (None, 1, 1, 1152)   28801       block6c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_dwcon
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 1, 1, 1152)   0           block6c_bn[1][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[1][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 48)     110642      block6c_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6c_se_re
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6c_activation[1][0]
#                                                                  prune_low_magnitude_block6c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_pro (None, 1, 1, 192)    442370      block6c_se_excite[1][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6c_proje
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 1, 1, 192)    0           block6c_project_bn[1][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 1, 1, 192)    0           block6c_drop[1][0]
#                                                                  block6b_add[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_exp (None, 1, 1, 1152)   442370      block6c_add[1][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_expan
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 1, 1, 1152)   0           block6d_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_dwc (None, 1, 1, 1152)   28801       block6d_expand_activation[1][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_dwcon
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 1, 1, 1152)   0           block6d_bn[1][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[1][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 48)     110642      block6d_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6d_se_re
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6d_activation[1][0]
#                                                                  prune_low_magnitude_block6d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_pro (None, 1, 1, 192)    442370      block6d_se_excite[1][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6d_proje
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 1, 1, 192)    0           block6d_project_bn[1][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 1, 1, 192)    0           block6d_drop[1][0]
#                                                                  block6c_add[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, 1, 1, 1152)   442370      block6d_add[1][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 1, 1, 1152)   0           block7a_expand_bn[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_dwc (None, 1, 1, 1152)   10369       block7a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_dwcon
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 1, 1, 1152)   0           block7a_bn[1][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[1][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 48)     110642      block7a_se_reshape[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 1, 1, 1152)   0           block7a_activation[1][0]
#                                                                  prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, 1, 1, 320)    737282      block7a_se_excite[1][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 1, 1, 320)    1280        prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_top_conv (P (None, 1, 1, 1280)   819202      block7a_project_bn[1][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 1, 1, 1280)   5120        prune_low_magnitude_top_conv[0][0
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 1, 1, 1280)   0           top_bn[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           top_activation[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense1 (None, 256)          655618      global_average_pooling2d[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense2 (None, 100)          51302       prune_low_magnitude_AddedDense1[0
# ==================================================================================================
# Total params: 8,530,813
# Trainable params: 4,361,184
# Non-trainable params: 4,169,629
# __________________________________________________________________________________________________

# %%
model_for_pruning_6.fit(x_train, y_train, batch_size=64, epochs=6, validation_data=(x_test, y_test), callbacks = [pruning_callbacks.UpdatePruningStep()])
# Out:
# Epoch 1/6
# 782/782 [==============================] - 67s 86ms/step - loss: 3.9697 - accuracy: 0.6845 - val_loss: 4.0864 - val_accuracy: 0.5438
# Epoch 2/6
# 782/782 [==============================] - 65s 83ms/step - loss: 3.8684 - accuracy: 0.7695 - val_loss: 4.0756 - val_accuracy: 0.5517
# Epoch 3/6
# 782/782 [==============================] - 65s 83ms/step - loss: 3.8363 - accuracy: 0.7978 - val_loss: 4.0750 - val_accuracy: 0.5545
# Epoch 4/6
# 782/782 [==============================] - 64s 82ms/step - loss: 3.8196 - accuracy: 0.8124 - val_loss: 4.0709 - val_accuracy: 0.5553
# Epoch 5/6
# 782/782 [==============================] - 65s 83ms/step - loss: 3.8092 - accuracy: 0.8225 - val_loss: 4.0695 - val_accuracy: 0.5552
# Epoch 6/6
# 782/782 [==============================] - 64s 82ms/step - loss: 3.8031 - accuracy: 0.8268 - val_loss: 4.0706 - val_accuracy: 0.5545

# %%
model_for_export_6 = tfmot.sparsity.keras.strip_pruning(model_for_pruning_6)
_, pruned_keras_file_6 = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export_6, pruned_keras_file_6, include_optimizer=False)
print('Saved pruned Keras model to:', pruned_keras_file_6)
# Out:
# Saved pruned Keras model to: /tmp/tmpxl7jn1rh.h5

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export_6)
pruned_tflite_model_6 = converter.convert()

_, pruned_tflite_file_6 = tempfile.mkstemp('.tflite')

with open(pruned_tflite_file_6, 'wb') as f:
    f.write(pruned_tflite_model_6)

print('Saved pruned TFLite model to:', pruned_tflite_file_6)
# print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_2)))
# print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_4)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_6)))
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpkrt3_6pw/assets
# INFO:tensorflow:Assets written to: /tmp/tmpkrt3_6pw/assets
# Saved pruned TFLite model to: /tmp/tmp2kb785iq.tflite
# Size of gzipped pruned and quantized TFlite model: 8907159.00 bytes

# %%
_, model_for_pruning_6_accuracy = model_for_pruning_6.evaluate(
   x_test, y_test, verbose=0)

print('Baseline test accuracy:', baseline_model_accuracy) 
# print('Pruned at 0.2 Sparsity test accuracy:', model_for_pruning_2_accuracy)
# print('Pruned at 0.4 Sparsity test accuracy:', model_for_pruning_4_accuracy)
print('Pruned at 0.6 Sparsity test accuracy:', model_for_pruning_6_accuracy)
# Out:
# Baseline test accuracy: 0.5666999816894531
# Pruned at 0.6 Sparsity test accuracy: 0.5544999837875366

# %%
# !ls /tmp/tmppanw888p.h5 -lh
# Out:
# -rw------- 1 jupyter jupyter 18M Apr 21 21:20 /tmp/tmppanw888p.h5

# %% [markdown]
# #### Pruning at 0.8 Sparsity

# %%
def apply_pruning_to_dense(layer):
    if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, ps)
    return layer

ps = pruning_schedule.PolynomialDecay(
                 initial_sparsity=0.80, final_sparsity=0.80,
                       begin_step=0, end_step=end_step, frequency=100)

model_for_pruning_8 = tf.keras.models.clone_model(
    model,
    clone_function=apply_pruning_to_dense,
)

# `prune_low_magnitude` requires a recompile.
model_for_pruning_8.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_for_pruning_8.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 32, 32, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# normalization_1 (Normalization) (None, 32, 32, 3)    7           rescaling_1[3][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 33, 33, 3)    0           normalization_1[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_conv ( (None, 16, 16, 32)   1730        stem_conv_pad[3][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 16, 16, 32)   128         prune_low_magnitude_stem_conv[0][
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 16, 16, 32)   0           stem_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_dwc (None, 16, 16, 32)   289         stem_activation[3][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 16, 16, 32)   128         prune_low_magnitude_block1a_dwcon
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 16, 16, 32)   0           block1a_bn[3][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[3][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 8)      522         block1a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 32)     546         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 16, 16, 32)   0           block1a_activation[3][0]
#                                                                  prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, 16, 16, 16)   1026        block1a_se_excite[3][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 16, 16, 16)   64          prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, 16, 16, 96)   3074        block1a_project_bn[3][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 16, 16, 96)   384         prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 16, 16, 96)   0           block2a_expand_bn[3][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 17, 17, 96)   0           block2a_expand_activation[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_dwc (None, 8, 8, 96)     865         block2a_dwconv_pad[3][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 8, 8, 96)     384         prune_low_magnitude_block2a_dwcon
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 8, 8, 96)     0           block2a_bn[3][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[3][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 4)      774         block2a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 96)     866         prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 8, 8, 96)     0           block2a_activation[3][0]
#                                                                  prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, 8, 8, 24)     4610        block2a_se_excite[3][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, 8, 8, 144)    6914        block2a_project_bn[3][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 8, 8, 144)    0           block2b_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dwc (None, 8, 8, 144)    1297        block2b_expand_activation[3][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 8, 8, 144)    576         prune_low_magnitude_block2b_dwcon
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 8, 8, 144)    0           block2b_bn[3][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[3][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 6)      1736        block2b_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 8, 8, 144)    0           block2b_activation[3][0]
#                                                                  prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, 8, 8, 24)     6914        block2b_se_excite[3][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 8, 8, 24)     96          prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 8, 8, 24)     0           block2b_project_bn[3][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 8, 8, 24)     0           block2b_drop[3][0]
#                                                                  block2a_project_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, 8, 8, 144)    6914        block2b_add[3][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 8, 8, 144)    576         prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 8, 8, 144)    0           block3a_expand_bn[3][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 11, 11, 144)  0           block3a_expand_activation[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_dwc (None, 4, 4, 144)    3601        block3a_dwconv_pad[3][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 4, 4, 144)    576         prune_low_magnitude_block3a_dwcon
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 4, 4, 144)    0           block3a_bn[3][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[3][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 6)      1736        block3a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 4, 4, 144)    0           block3a_activation[3][0]
#                                                                  prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, 4, 4, 40)     11522       block3a_se_excite[3][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, 4, 4, 240)    19202       block3a_project_bn[3][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 4, 4, 240)    0           block3b_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dwc (None, 4, 4, 240)    6001        block3b_expand_activation[3][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 4, 4, 240)    960         prune_low_magnitude_block3b_dwcon
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 4, 4, 240)    0           block3b_bn[3][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[3][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 10)     4812        block3b_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 4, 4, 240)    0           block3b_activation[3][0]
#                                                                  prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, 4, 4, 40)     19202       block3b_se_excite[3][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 4, 4, 40)     160         prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 4, 4, 40)     0           block3b_project_bn[3][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 4, 4, 40)     0           block3b_drop[3][0]
#                                                                  block3a_project_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, 4, 4, 240)    19202       block3b_add[3][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 4, 4, 240)    960         prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 4, 4, 240)    0           block4a_expand_bn[3][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 5, 5, 240)    0           block4a_expand_activation[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_dwc (None, 2, 2, 240)    2161        block4a_dwconv_pad[3][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 2, 2, 240)    960         prune_low_magnitude_block4a_dwcon
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 2, 2, 240)    0           block4a_bn[3][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[3][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 10)     4812        block4a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 240)    5042        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 2, 2, 240)    0           block4a_activation[3][0]
#                                                                  prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, 2, 2, 80)     38402       block4a_se_excite[3][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, 2, 2, 480)    76802       block4a_project_bn[3][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 2, 2, 480)    0           block4b_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dwc (None, 2, 2, 480)    4321        block4b_expand_activation[3][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4b_dwcon
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 2, 2, 480)    0           block4b_bn[3][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[3][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 20)     19222       block4b_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 2, 2, 480)    0           block4b_activation[3][0]
#                                                                  prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, 2, 2, 80)     76802       block4b_se_excite[3][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 2, 2, 80)     0           block4b_project_bn[3][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 2, 2, 80)     0           block4b_drop[3][0]
#                                                                  block4a_project_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, 2, 2, 480)    76802       block4b_add[3][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 2, 2, 480)    0           block4c_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dwc (None, 2, 2, 480)    4321        block4c_expand_activation[3][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block4c_dwcon
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 2, 2, 480)    0           block4c_bn[3][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[3][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 20)     19222       block4c_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 2, 2, 480)    0           block4c_activation[3][0]
#                                                                  prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, 2, 2, 80)     76802       block4c_se_excite[3][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 2, 2, 80)     320         prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 2, 2, 80)     0           block4c_project_bn[3][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 2, 2, 80)     0           block4c_drop[3][0]
#                                                                  block4b_add[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, 2, 2, 480)    76802       block4c_add[3][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 2, 2, 480)    0           block5a_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_dwc (None, 2, 2, 480)    12001       block5a_expand_activation[3][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 2, 2, 480)    1920        prune_low_magnitude_block5a_dwcon
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 2, 2, 480)    0           block5a_bn[3][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[3][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 20)     19222       block5a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 480)    19682       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 2, 2, 480)    0           block5a_activation[3][0]
#                                                                  prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, 2, 2, 112)    107522      block5a_se_excite[3][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, 2, 2, 672)    150530      block5a_project_bn[3][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 2, 2, 672)    0           block5b_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dwc (None, 2, 2, 672)    16801       block5b_expand_activation[3][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5b_dwcon
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 2, 2, 672)    0           block5b_bn[3][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[3][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 28)     37662       block5b_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 2, 2, 672)    0           block5b_activation[3][0]
#                                                                  prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, 2, 2, 112)    150530      block5b_se_excite[3][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 2, 2, 112)    0           block5b_project_bn[3][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 2, 2, 112)    0           block5b_drop[3][0]
#                                                                  block5a_project_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, 2, 2, 672)    150530      block5b_add[3][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 2, 2, 672)    0           block5c_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dwc (None, 2, 2, 672)    16801       block5c_expand_activation[3][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 2, 2, 672)    2688        prune_low_magnitude_block5c_dwcon
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 2, 2, 672)    0           block5c_bn[3][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[3][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 28)     37662       block5c_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 2, 2, 672)    0           block5c_activation[3][0]
#                                                                  prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, 2, 2, 112)    150530      block5c_se_excite[3][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 2, 2, 112)    448         prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 2, 2, 112)    0           block5c_project_bn[3][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 2, 2, 112)    0           block5c_drop[3][0]
#                                                                  block5b_add[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_exp (None, 2, 2, 672)    150530      block5c_add[3][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 2, 2, 672)    2688        prune_low_magnitude_block6a_expan
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 2, 2, 672)    0           block6a_expand_bn[3][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 5, 5, 672)    0           block6a_expand_activation[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_dwc (None, 1, 1, 672)    16801       block6a_dwconv_pad[3][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 1, 1, 672)    2688        prune_low_magnitude_block6a_dwcon
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 1, 1, 672)    0           block6a_bn[3][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[3][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 28)     37662       block6a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_se_ (None, 1, 1, 672)    38306       prune_low_magnitude_block6a_se_re
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 1, 1, 672)    0           block6a_activation[3][0]
#                                                                  prune_low_magnitude_block6a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6a_pro (None, 1, 1, 192)    258050      block6a_se_excite[3][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_exp (None, 1, 1, 1152)   442370      block6a_project_bn[3][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_expan
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 1, 1, 1152)   0           block6b_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_dwc (None, 1, 1, 1152)   28801       block6b_expand_activation[3][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6b_dwcon
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 1, 1, 1152)   0           block6b_bn[3][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[3][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 48)     110642      block6b_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6b_se_re
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6b_activation[3][0]
#                                                                  prune_low_magnitude_block6b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6b_pro (None, 1, 1, 192)    442370      block6b_se_excite[3][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6b_proje
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 1, 1, 192)    0           block6b_project_bn[3][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 1, 1, 192)    0           block6b_drop[3][0]
#                                                                  block6a_project_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_exp (None, 1, 1, 1152)   442370      block6b_add[3][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_expan
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 1, 1, 1152)   0           block6c_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_dwc (None, 1, 1, 1152)   28801       block6c_expand_activation[3][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6c_dwcon
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 1, 1, 1152)   0           block6c_bn[3][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[3][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 48)     110642      block6c_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6c_se_re
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6c_activation[3][0]
#                                                                  prune_low_magnitude_block6c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6c_pro (None, 1, 1, 192)    442370      block6c_se_excite[3][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6c_proje
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 1, 1, 192)    0           block6c_project_bn[3][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 1, 1, 192)    0           block6c_drop[3][0]
#                                                                  block6b_add[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_exp (None, 1, 1, 1152)   442370      block6c_add[3][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_expan
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 1, 1, 1152)   0           block6d_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_dwc (None, 1, 1, 1152)   28801       block6d_expand_activation[3][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block6d_dwcon
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 1, 1, 1152)   0           block6d_bn[3][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[3][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 48)     110642      block6d_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block6d_se_re
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 1, 1, 1152)   0           block6d_activation[3][0]
#                                                                  prune_low_magnitude_block6d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block6d_pro (None, 1, 1, 192)    442370      block6d_se_excite[3][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 1, 1, 192)    768         prune_low_magnitude_block6d_proje
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 1, 1, 192)    0           block6d_project_bn[3][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 1, 1, 192)    0           block6d_drop[3][0]
#                                                                  block6c_add[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, 1, 1, 1152)   442370      block6d_add[3][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 1, 1, 1152)   0           block7a_expand_bn[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_dwc (None, 1, 1, 1152)   10369       block7a_expand_activation[3][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 1, 1, 1152)   4608        prune_low_magnitude_block7a_dwcon
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 1, 1, 1152)   0           block7a_bn[3][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[3][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 48)     110642      block7a_se_reshape[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1152)   111746      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 1, 1, 1152)   0           block7a_activation[3][0]
#                                                                  prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, 1, 1, 320)    737282      block7a_se_excite[3][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 1, 1, 320)    1280        prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_top_conv (P (None, 1, 1, 1280)   819202      block7a_project_bn[3][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 1, 1, 1280)   5120        prune_low_magnitude_top_conv[0][0
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 1, 1, 1280)   0           top_bn[3][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           top_activation[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense1 (None, 256)          655618      global_average_pooling2d[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_AddedDense2 (None, 100)          51302       prune_low_magnitude_AddedDense1[0
# ==================================================================================================
# Total params: 8,530,813
# Trainable params: 4,361,184
# Non-trainable params: 4,169,629
# __________________________________________________________________________________________________

# %%
model_for_pruning_8.fit(x_train, y_train, batch_size=64, epochs=6, validation_data=(x_test, y_test), callbacks = [pruning_callbacks.UpdatePruningStep()])
# Out:
# Epoch 1/6
# 782/782 [==============================] - 66s 84ms/step - loss: 4.2879 - accuracy: 0.3439 - val_loss: 4.2250 - val_accuracy: 0.4041
# Epoch 2/6
# 782/782 [==============================] - 65s 83ms/step - loss: 4.1356 - accuracy: 0.4960 - val_loss: 4.1794 - val_accuracy: 0.4466
# Epoch 3/6
# 782/782 [==============================] - 64s 82ms/step - loss: 4.0763 - accuracy: 0.5545 - val_loss: 4.1527 - val_accuracy: 0.4752
# Epoch 4/6
# 782/782 [==============================] - 64s 82ms/step - loss: 4.0422 - accuracy: 0.5871 - val_loss: 4.1377 - val_accuracy: 0.4894
# Epoch 5/6
# 782/782 [==============================] - 65s 83ms/step - loss: 4.0170 - accuracy: 0.6122 - val_loss: 4.1244 - val_accuracy: 0.5032
# Epoch 6/6
# 782/782 [==============================] - 64s 81ms/step - loss: 3.9979 - accuracy: 0.6303 - val_loss: 4.1207 - val_accuracy: 0.5059

# %%
_, model_for_pruning_8_accuracy = model_for_pruning_8.evaluate(
   x_test, y_test, verbose=0)

# print('Baseline test accuracy:', baseline_model_accuracy) 
# print('Pruned at 0.2 Sparsity test accuracy:', model_for_pruning_2_accuracy)
# print('Pruned at 0.4 Sparsity test accuracy:', model_for_pruning_4_accuracy)
print('Pruned at 0.6 Sparsity test accuracy:', model_for_pruning_6_accuracy)
print('Pruned at 0.8 Sparsity test accuracy:', model_for_pruning_8_accuracy)
# Out:
# Pruned at 0.6 Sparsity test accuracy: 0.5544999837875366
# Pruned at 0.8 Sparsity test accuracy: 0.5059000253677368

# %%
model_for_export_8 = tfmot.sparsity.keras.strip_pruning(model_for_pruning_8)
_, pruned_keras_file_8 = tempfile.mkstemp('.h5')
tf.keras.models.save_model(model_for_export_8, pruned_keras_file_8, include_optimizer=False)
print('Saved pruned Keras model to:', pruned_keras_file_8)
# Out:
# Saved pruned Keras model to: /tmp/tmpi82jouta.h5

# %%
# !ls /tmp/tmpoy2b62fo.h5 -lh
# Out:
# -rw------- 1 jupyter jupyter 18M Apr 21 21:20 /tmp/tmpoy2b62fo.h5

# %% [markdown]
# #### Convert models to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export_8)
pruned_tflite_model_8 = converter.convert()

_, pruned_tflite_file_8 = tempfile.mkstemp('.tflite')

with open(pruned_tflite_file_8, 'wb') as f:
    f.write(pruned_tflite_model_8)

print('Saved pruned TFLite model to:', pruned_tflite_file_8)
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_2)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_4)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_6)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_8)))
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpd4w7cdsj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpd4w7cdsj/assets
# Saved pruned TFLite model to: /tmp/tmpszu1bvlw.tflite
# Size of gzipped pruned and quantized TFlite model: 8907159.00 bytes
# Size of gzipped pruned and quantized TFlite model: 5756089.00 bytes

# %% [markdown]
# ### Pruning and Quantization

# %%
def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_for_export_6)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_and_pruned_tflite_model = converter.convert()

_, quantized_and_pruned_tflite_file = tempfile.mkstemp('.tflite')

with open(quantized_and_pruned_tflite_file, 'wb') as f:
    f.write(quantized_and_pruned_tflite_model)

print('Saved quantized and pruned TFLite model to:', quantized_and_pruned_tflite_file)

print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(quantized_and_pruned_tflite_file)))
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpv7b2t0j4/assets
# INFO:tensorflow:Assets written to: /tmp/tmpv7b2t0j4/assets
# Saved quantized and pruned TFLite model to: /tmp/tmpw67za2sw.tflite
# Size of gzipped baseline Keras model: 16421810.00 bytes
# Size of gzipped pruned and quantized TFlite model: 1638074.00 bytes

# %%
print("Size of gzipped baseline Keras model: %.2f bytes" % (get_gzipped_model_size(keras_file)))
print("Size of gzipped pruned TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_2)))
print("Size of gzipped pruned TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_4)))
print("Size of gzipped pruned TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_6)))
print("Size of gzipped pruned TFlite model: %.2f bytes" % (get_gzipped_model_size(pruned_tflite_file_8)))
print("Size of gzipped pruned and quantized TFlite model: %.2f bytes" % (get_gzipped_model_size(quantized_and_pruned_tflite_file)))
# Out:
# Size of gzipped baseline Keras model: 16421810.00 bytes
# Size of gzipped pruned TFlite model: 8907159.00 bytes
# Size of gzipped pruned TFlite model: 5756089.00 bytes
# Size of gzipped pruned and quantized TFlite model: 1638074.00 bytes

# %%
y_test = np.argmax(y_test, axis=1)

# %%
import numpy as np

def evaluate_model(interpreter):
#     global prediction_digits
    prediction_digits = []
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]

  # Run predictions on ever y image in the "test" dataset.
    for i, test_image in enumerate(x_test):
        if i % 1000 == 0:
            print('Evaluated on {n} results so far.'.format(n=i))
        # Pre-processing: add batch dimension and convert to float32 to match with
        # the model's input data format.
        test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
        interpreter.set_tensor(input_index, test_image)

        # Run inference.
        interpreter.invoke()

        # Post-processing: remove batch dimension and find the digit with highest
        # probability.
        output = interpreter.tensor(output_index)
        digit = np.argmax(output()[0])
        prediction_digits.append(digit)

    print('\n')
    # Compare prediction results with ground truth labels to calculate accuracy.
    prediction_digits = np.array(prediction_digits)
    accuracy = (prediction_digits == y_test).mean()
    return accuracy

# %%
interpreter = tf.lite.Interpreter(model_content=quantized_and_pruned_tflite_model)
interpreter.allocate_tensors()

test_accuracy = evaluate_model(interpreter)

print('Pruned and quantized TFLite test_accuracy:', test_accuracy)
# Out:
# Evaluated on 0 results so far.
# Evaluated on 1000 results so far.
# Evaluated on 2000 results so far.
# Evaluated on 3000 results so far.
# Evaluated on 4000 results so far.
# Evaluated on 5000 results so far.
# Evaluated on 6000 results so far.
# Evaluated on 7000 results so far.
# Evaluated on 8000 results so far.
# Evaluated on 9000 results so far.
#
#
# Pruned and quantized TFLite test_accuracy: 0.4219
